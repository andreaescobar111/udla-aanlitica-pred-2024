# %% [markdown]
# Hola esta es mi sesión 2 y mi primera interacción con python

# %% [markdown]
# **Negrita**

# %%
# prompt: haz un print del siguiente texto "hola mundo"

print("hola mundo")
# Out:
# hola mundo

# %%
# prompt: suma 3 valores aleatorios

import random

def suma_tres_aleatorios():
  """Suma tres números aleatorios entre 1 y 10."""
  num1 = random.randint(1, 10)
  num2 = random.randint(1, 10)
  num3 = random.randint(1, 10)
  suma = num1 + num2 + num3
  return suma

# Ejemplo de uso
resultado = suma_tres_aleatorios()
print(f"La suma de los tres números aleatorios es: {resultado}")
# Out:
# La suma de los tres números aleatorios es: 24

# %%
# prompt: suma tres valores aleatorios

def suma_tres_aleatorios():
  """Suma tres números aleatorios entre 1 y 10."""
  num1 = random.randint(1, 10)
  num2 = random.randint(1, 10)
  num3 = random.randint(1, 10)
  suma = num1 + num2 + num3
  return suma
